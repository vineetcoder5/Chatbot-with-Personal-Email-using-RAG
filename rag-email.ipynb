# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/email-dataset/Untitled spreadsheet - mail (1).csv

# %%
file_path = "/kaggle/input/email-dataset/Untitled spreadsheet - mail (1).csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#                 data                                            subject  \
# 0  2/4/2024 16:54:56  New assignment: "Assignment-I (Submit Within T...
# 1  2/4/2024 22:14:55  🔴 10PM Chat is Currently Live | Enjoy the Weekend
# 2  2/4/2024 22:32:27  Anyone who attended the KIITFEST opening ceremony
# 3  2/4/2024 22:55:26  INTERNSHIP DRIVE FOR KIIT STUDENTS WITH COLLAB...
# 4  2/5/2024 13:58:36  Industrial Internship Opportunities for KIIT S...
#
#                                                email  \
# 0  "Dr. Sudipta K. Ghosh (Classroom)" <no-reply@c...
# 1                 KIIT-CONNECT <21053420@kiit.ac.in>
# 2                 113_AYUSH DAS <2105113@kiit.ac.in>
# 3        bunga maulika <bunga.maulika@teachnook.com>
# 4                    046_SHIVAM <1907046@kiit.ac.in>
#
#                                                 body
# 0  \nNotification settings  \n<https://accounts.g...
# 1   Weekly Chat Notification \n[image: Event Logo...
# 2  Anyone who has attended the KIITFEST opening c...
# 3  Dear *KIIT *Student,* Congratulations on being...
# 4  Welcome to Internz Learn!\r\n\r\nNow is the pe...

# %%
def combine_sentense(row):
    # Split the sentence into words
    return "date and time: "+str(row['data'])+"\nsubject: "+str(row['subject'])+"\nfrom: "+str(row['email'])+"\n\n"+row['body'] 

df['complete_email'] = df.apply(combine_sentense, axis=1)

# %%
df['complete_email'][10]
# Out:
# "date and time: 2/5/2024 22:21:54\nsubject: Recruitment Mail | GeeksForGeeks KIIT\nfrom: PRIYA MISHRA <22052922@kiit.ac.in>\n\n*Recruitment 2024*\r\n\r\n\r\nHola Geeks! GeekForGeeks KIIT Chapter is looking for all tech and non tech\r\nenthusiasts for its teams. The details regarding all the necessary domains\r\nhave been given in the website. Click on the Register Button to apply!!\r\nClick To Register <https://gfgrecweb.web.app/>\r\n[image: Facebook icon] <https://facebook.com/> [image: Instagram icon]\r\n<https://www.instagram.com/gfg_kiit?igsh=NHl0NXE3ZHk0OWU0> [image: Website\r\nicon] <https://gfgrecweb.web.app/>\r\n[image: Logo]\r\n\r\n\r\n[image: Email Marketing Powered by Mailchimp] <http://eepurl.com/iG88B6>\r\nRegards,\r\nTeam GeeksForGeeks KIIT.\r\n\r\n-- \r\n\r\n\r\n* <http://www.kiit.ac.in>*\r\n\r\n*\r\nGo Green: Kindly don't print this unless so \r\nrequired.*\r\n\r\n*\r\n*\r\n\r\n*Established\xa0U/S\xa03\xa0of\xa0UGC\xa0Act\xa0and\xa0Accredited\xa0by\xa0NBA\xa0of\xa0\r\nAICTE\xa0and\xa0NAAC\xa0of\xa0UGC*\r\n\r\n\r\n\r\nVisit us @\xa0*http://www.kiit.ac.in \r\n<http://www.kiit.ac.in/>*\r\n\r\nFollow us @*\xa0**|***Twitter \r\n<https://www.twitter.com/KIITUniversity/>***|***Facebook** \r\n<https://www.facebook.com/KIITUniversity>*|***Instagram \r\n<https://www.instagram.com/KIITUniversity/>***|*\r\n\r\n\r\n \r\n  \r\n  \r\n\r\nThe information \r\ncontained in this electronic message and any\r\n  attachments to this message \r\nare intended for the exclusive use of the\r\n  addressee(s) and may contain \r\nproprietary, confidential or privileged\r\n  information. If you are not the \r\nintended recipient, you should not\r\n  disseminate, distribute or copy this \r\ne-mail. Please notify the sender\r\n  immediately and delete all copies of \r\nthis message and any attachments.\r\n  \r\n\r\n\xa0VIRUS WARNING: Computer viruses can \r\nbe\r\n  transmitted via email. The recipient should check this email and any\r\n  \r\nattachments for the presence of viruses. The institute accepts no liability\r\n  for any damage caused by any virus transmitted by this email.\r\n  \r\n\r\n \r\n\r\n\r\n\r\n\r\n\r\n\r\n"

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="YOUR_API_KEY")

# %%
def embed_text(text):
    result = genai.embed_content(model="models/text-embedding-004", content=text['complete_email'][:2000])
    return result['embedding']

# %%
df['embedding'] = df.apply(embed_text, axis=1)

# %%
df.to_pickle("email_embed.pkl")

# %%
df.head()
# Out:
#                 data                                            subject  \
# 0  2/4/2024 16:54:56  New assignment: "Assignment-I (Submit Within T...
# 1  2/4/2024 22:14:55  🔴 10PM Chat is Currently Live | Enjoy the Weekend
# 2  2/4/2024 22:32:27  Anyone who attended the KIITFEST opening ceremony
# 3  2/4/2024 22:55:26  INTERNSHIP DRIVE FOR KIIT STUDENTS WITH COLLAB...
# 4  2/5/2024 13:58:36  Industrial Internship Opportunities for KIIT S...
#
#                                                email  \
# 0  "Dr. Sudipta K. Ghosh (Classroom)" <no-reply@c...
# 1                 KIIT-CONNECT <21053420@kiit.ac.in>
# 2                 113_AYUSH DAS <2105113@kiit.ac.in>
# 3        bunga maulika <bunga.maulika@teachnook.com>
# 4                    046_SHIVAM <1907046@kiit.ac.in>
#
#                                                 body  \
# 0  \nNotification settings  \n<https://accounts.g...
# 1   Weekly Chat Notification \n[image: Event Logo...
# 2  Anyone who has attended the KIITFEST opening c...
# 3  Dear *KIIT *Student,* Congratulations on being...
# 4  Welcome to Internz Learn!\r\n\r\nNow is the pe...
#
#                                       complete_email  \
# 0  date and time: 2/4/2024 16:54:56\nsubject: New...
# 1  date and time: 2/4/2024 22:14:55\nsubject: 🔴 1...
# 2  date and time: 2/4/2024 22:32:27\nsubject: Any...
# 3  date and time: 2/4/2024 22:55:26\nsubject: INT...
# 4  date and time: 2/5/2024 13:58:36\nsubject: Ind...
#
#                                            embedding
# 0  [0.04024537, 0.058987156, -0.045412473, 0.0061...
# 1  [0.05177241, 0.007969351, -0.01676914, -0.0163...
# 2  [0.0015230135, 0.007805147, -0.029218256, -0.0...
# 3  [0.048756287, -0.035063192, -0.025831053, -0.0...
# 4  [0.046176463, -0.041782457, -0.053905442, -0.0...

# %%
def distance(text):
    return np.dot(text['embedding'],text['question'])

# %%
genai.configure(api_key="YOUR_API_KEY")

# Create the model
# See https://ai.google.dev/api/python/google/generativeai/GenerativeModel
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 100000,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
  system_instruction= 'You are a personal assistant who is helping vineet to resond to question based on the emails',
)

# %%
chat_session = model.start_chat(
  history=[
  ]
)

# %%
def query_answer(question,df,k=5):
    question_embd = genai.embed_content(model="models/text-embedding-004", content=question)
    emb = question_embd['embedding']
    def questio(row):
        return emb
    df['question'] = df.apply(questio, axis=1)
    df['distance'] = df.apply(distance, axis=1)
    sorted_df = df.sort_values('distance', ascending=False, inplace=False)
    def combine_email(k=5):
        text = ""
        for i in range(k):
            text += sorted_df['complete_email'].iloc[i]+'\n\n'
        return text
    question_model = question+"\n\n"+"use this informattion from vineet email as context to answer the question\n"+combine_email(k)+"\n .please stick to this context to answer the question and only give answer dont give information where i can find it" 
    response = chat_session.send_message(question_model)
    return response.text
print(query_answer("who is dbms teacher",df,10))
# Out:
# Dr. Rajat Kumar Behera is the DBMS teacher.

# %%
print(query_answer("Which university do I study in and it is in which state",df,10))
# Out:
# You study at Kalinga Institute of Industrial Technology (KIIT) Deemed to be University, located in Bhubaneswar, Odisha.

# %%
print(query_answer("who is archuta samantar",df,10))
# Out:
# Archuta Samanta is the Hon'ble Founder of KIIT & KISS.

# %%
print(query_answer("who is the dean ",df,10))
# Out:
# Dr. Amulya Ratna Swain is the Dean of the School of Computer Engineering.

# %%
print(query_answer("who is my os teacher",df,10))
# Out:
# Your OS teacher is Dr. Sampriti Soor.

# %%
print(query_answer("what subjects i have studed in the collage with teacher name",df,15))
# Out:
# Here are the subjects you've studied in college, along with the teacher's name:
#
# * **Data Structure (CS-21001) and Data Structure Lab (CS-29001)** - Dr. Satyananda Champati Rai
# * **Basic Electronics (EC10001)** - Prof. Anupama Senapati
# * **Scientific and Technical Writing (EX-20003)** -  (Teacher name not provided, but you can find it on the student view portal)
# * **Probability and Statistics (MA21001)** -  (Teacher name not provided, but you can find it on the student view portal)
# * **Digital Systems Design (EC-20005) and Digital Systems Design Laboratory (EC29005)** - (Teacher name not provided, but you can find it on the student view portal)
# * **Object Oriented Programming (CM20004) and Java Programming Laboratory (CM29004)** - (Teacher name not provided, but you can find it on the student view portal)
# * **Computer Organization and Architecture (CM21002) and Computer Organization and Architecture Laboratory (CM29002)** - (Teacher name not provided, but you can find it on the student view portal)
# * **Industry 4.0 Technologies (EX-20001)** - (Teacher name not provided, but you can find it on the student view portal)
# * **HASS Economics of Development (HS20120)** - (Teacher name not provided, but you can find it on the student view portal)
# * **HASS-International Economic Cooperation (HS20122)** - (Teacher name not provided, but you can find it on the student view portal)
# * **Basic Mechanical Engineering (ME28017)** - (Teacher name not provided, but you can find it on the student view portal)
# * **Transforms and Numerical Methods (MA21002)** - (Teacher name not provided, but you can find it on the student view portal)
#
# You can use the KIIT-CONNECT platform to find the specific teachers for the courses where the names are missing.
